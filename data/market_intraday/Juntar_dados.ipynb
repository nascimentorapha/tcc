# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
vale_1 = pd.read_csv('/content/drive/My Drive/TCC/Intraday_Historical/VALE.csv')
vale_2 = pd.read_csv('/content/drive/My Drive/TCC/Intraday_Historical/VALE_new.csv')
vale_1 = vale_1.drop(['Unnamed: 0'], axis=1)
#count_row = vale_2.shape[0]
#count_row

vale = vale_1.append(vale_2, ignore_index=True)
vale.set_index('date')
count_row = vale.shape[0]
count_row
vale.to_csv('/content/drive/My Drive/TCC/Intraday_Historical/VALE.csv')

# %%
ggb_1 = pd.read_csv('/content/drive/My Drive/TCC/Intraday_Historical/GGB.csv')
ggb_2 = pd.read_csv('/content/drive/My Drive/TCC/Intraday_Historical/GGB_new.csv')
ggb_1 = ggb_1.drop(['Unnamed: 0'], axis=1)
count_row = ggb_2.shape[0]
count_row

ggb = ggb_1.append(ggb_2, ignore_index=True)
ggb.set_index('date')
count_row = ggb.shape[0]
count_row
ggb.to_csv('/content/drive/My Drive/TCC/Intraday_Historical/GGB.csv')

# %%
pbr_1 = pd.read_csv('/content/drive/My Drive/TCC/Intraday_Historical/PBR.csv')
pbr_2 = pd.read_csv('/content/drive/My Drive/TCC/Intraday_Historical/PBR_new.csv')
pbr_1 = pbr_1.drop(['Unnamed: 0'], axis=1)
count_row = pbr_2.shape[0]
count_row

pbr = pbr_1.append(pbr_2, ignore_index = True)
pbr.set_index('date')
count_row = pbr.shape[0]
count_row
pbr.to_csv('/content/drive/My Drive/TCC/Intraday_Historical/PBR.csv')

# %%
sid_1 = pd.read_csv('/content/drive/My Drive/TCC/Intraday_Historical/SID.csv')
sid_2 = pd.read_csv('/content/drive/My Drive/TCC/Intraday_Historical/SID_new.csv')
sid_1 = sid_1.drop(['Unnamed: 0'], axis = 1)
count_row = sid_1.shape[0]
count_row

sid = sid_1.append(sid_2, ignore_index=True)
sid.set_index('date')
count_row = sid.shape[0]
count_row
sid.to_csv('/content/drive/My Drive/TCC/Intraday_Historical/SID.csv')

# %%
suz_1 = pd.read_csv('/content/drive/My Drive/TCC/Intraday_Historical/SUZ.csv')
suz_2 = pd.read_csv('/content/drive/My Drive/TCC/Intraday_Historical/SUZ_new.csv')
suz_1 = suz_1.drop(['Unnamed: 0'], axis = 1)
count_row = suz_2.shape[0]
count_row

suz = suz_1.append(suz_2, ignore_index=True)
suz.set_index('date')
count_row = suz.shape[0]
count_row
suz.to_csv('/content/drive/My Drive/TCC/Intraday_Historical/SUZ.csv')
