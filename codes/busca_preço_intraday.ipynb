# %%
#install the alpha vantage API
# !pip install alpha_vantage
# Out:
# ...
#   Created wheel for alpha-vantage: filename=alpha_vantage-2.1.3-cp36-none-any.whl size=14870 sha256=778839f3e68da72dc21b753c0761617f9350ac0bd4abf7815ba86669964c5c64
#   Stored in directory: /root/.cache/pip/wheels/d4/75/c2/483b0a988fd965b1128c1396a0ffadfb8903bd2bb569220048
# Successfully built alpha-vantage
# ...

# %%
#import libraries
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame

# %%
#set the key and the output format 
ALPHA_VANTAGE_API_KEY = 'PM1FHCT5G1YZ8KTW'
ts = TimeSeries(key=ALPHA_VANTAGE_API_KEY, output_format='pandas')

# %%
#selected the company: Petrobras (PBR)
intraday_data_PBR, data_info = ts.get_intraday(symbol='PBR', outputsize='full', interval='1min')

#Export the result to a csv
intraday_data_PBR.to_csv('PBR_new.csv')

# %%
#Verifying all the data
intraday_data_PBR['1. open'].plot()
plt.xticks(rotation='45', fontsize = 8)
plt.ylabel('Stock Price (R$)')
plt.xlabel('Date')
plt.title('Intraday Petrobrás (1 min)')
plt.show()

# %%
#looking at the dataset
intraday_data.head()
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2020-02-28 16:00:00   12.080    12.12   12.06   12.1100   304995.0
# 2020-02-28 15:59:00   12.070    12.08   12.05   12.0701   234217.0
# 2020-02-28 15:58:00   12.065    12.08   12.04   12.0650   654573.0
# 2020-02-28 15:57:00   12.000    12.07   12.00   12.0650   421498.0
# 2020-02-28 15:56:00   11.965    12.01   11.96   12.0000   367069.0

# %%
#selected the company: VALE (VALE)
intraday_data_VALE, data_info = ts.get_intraday(symbol='VALE', outputsize='full', interval='1min')
 
#Export the result to a csv
intraday_data_VALE.to_csv('VALE_new.csv')

# %%
#Verifying all the data
intraday_data_VALE.plot(x='date', y='1. open')
plt.xticks(rotation='45', fontsize = 8)
plt.ylabel('Stock Price (R$)')
plt.xlabel('Date')
plt.title('Intraday Vale S.A. (1 min)')
plt.show()

# %%
#drop the columns that we'll not use
pet2 = pet2.drop(['2. high'	,'3. low'	,'4. close', '5. volume'],1)
pet2.head()
