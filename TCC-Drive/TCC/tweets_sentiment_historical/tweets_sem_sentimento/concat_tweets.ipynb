# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd

# %%
oil1 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/TCC/tweets_sentiment_historical/tweets_sem_sentimento/oil_14_08.csv', sep=";")
oil2 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/TCC/tweets_sentiment_historical/tweets_sem_sentimento/oil_22_08.csv', sep=";")
oil3 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/TCC/tweets_sentiment_historical/tweets_sem_sentimento/oil_16_09.csv', sep=";")

# %%
oil = pd.concat([oil1, oil2, oil3], ignore_index=False)

# %%
oil.to_csv(r'/content/drive/My Drive/Colab Notebooks/TCC/tweets_sentiment_historical/oil_to_analyse.csv')
